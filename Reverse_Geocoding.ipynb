# %% [markdown]
# ## README
# The goal of this notebook is to create a mapping relation between the stations and the boroughs via reverse geocoding. The result is already saved in 'station_to_boro.csv'. You do NOT need to run this notebook.
# If you want to run this notebook,
# 1). be sure to install geopy beforehand
# 2). bear in mind that it takes about 30 minutes to run the notebook since there are about 1800 stations and I can only call the API once per second
# 3). it may run into timed-out errors and you have to start over or start from where you timed out

# %%
import pandas as pd
from geopy.geocoders import Nominatim
from geopy.extra.rate_limiter import RateLimiter

# %%
geolocator = Nominatim(user_agent="bikeshare")
reverse = RateLimiter(geolocator.reverse, min_delay_seconds=1, max_retries=0)

# %%
stations = pd.read_csv('stations.csv')

# %%
locations=[]
for index, row in stations.iterrows():
    locations.append(reverse("{}, {}".format(row['lat'],row['lng'])).raw['address'])
pd.DataFrame(locations[:10])
# Out:
#   house_number               road     suburb              city     state  \
# 0          356      Bergen Street   Brooklyn  City of New York  New York
# 1          NaN     Bedford Avenue   Brooklyn  City of New York  New York
# 2          NaN   West 20th Street  Manhattan  City of New York  New York
# 3          529         2nd Avenue  Manhattan  City of New York  New York
# 4          NaN  Cumberland Street   Brooklyn  City of New York  New York
# 5          NaN       Pearl Street  Manhattan  City of New York  New York
# 6          NaN   West 85th Street  Manhattan  City of New York  New York
# 7          NaN    East 2nd Street  Manhattan  City of New York  New York
# 8         1003  East 174th Street  The Bronx  City of New York  New York
# 9          NaN       Hanson Place   Brooklyn  City of New York  New York
#
#   ISO3166-2-lvl4 postcode        country country_code  \
# 0          US-NY    11217  United States           us
# 1          US-NY    11226  United States           us
# 2          US-NY    10011  United States           us
# 3          US-NY    10016  United States           us
# 4          US-NY    11238  United States           us
# 5          US-NY    10038  United States           us
# 6          US-NY    10024  United States           us
# 7          US-NY    10009  United States           us
# 8          US-NY    10460  United States           us
# 9          US-NY    11217  United States           us
#
#                                             amenity  \
# 0                                               NaN
# 1                                         Citi Bike
# 2         Citi Bike - West 20th Street & 8th Avenue
# 3                                               NaN
# 4  Citi Bike - Cumberland Street & Lafayette Avenue
# 5      Citi Bike - Saint James Place & Pearl Street
# 6                                               NaN
# 7            Citi Bike - East 2nd Street & Avenue B
# 8                                               NaN
# 9      Citi Bike - Hanson Place & Atlantic Terminal
#
#                  neighbourhood           county         building
# 0                          NaN              NaN              NaN
# 1                          NaN              NaN              NaN
# 2             Chelsea District  New York County              NaN
# 3  Manhattan Community Board 6  New York County              NaN
# 4                          NaN              NaN              NaN
# 5  Manhattan Community Board 3  New York County              NaN
# 6  Manhattan Community Board 7  New York County  Rossleigh Court
# 7                 East Village  New York County              NaN
# 8            Charlotte Gardens              NaN              NaN
# 9                          NaN              NaN              NaN

# %%
coord_to_boro = pd.DataFrame(locations)
len(coord_to_boro)
# Out:
# 1814

# %%
coord_to_boro.head()
# Out:
#   house_number               road     suburb              city     state  \
# 0          356      Bergen Street   Brooklyn  City of New York  New York
# 1          NaN     Bedford Avenue   Brooklyn  City of New York  New York
# 2          NaN   West 20th Street  Manhattan  City of New York  New York
# 3          529         2nd Avenue  Manhattan  City of New York  New York
# 4          NaN  Cumberland Street   Brooklyn  City of New York  New York
#
#   ISO3166-2-lvl4 postcode        country country_code  \
# 0          US-NY    11217  United States           us
# 1          US-NY    11226  United States           us
# 2          US-NY    10011  United States           us
# 3          US-NY    10016  United States           us
# 4          US-NY    11238  United States           us
#
#                                             amenity  ... residential historic  \
# 0                                               NaN  ...         NaN      NaN
# 1                                         Citi Bike  ...         NaN      NaN
# 2         Citi Bike - West 20th Street & 8th Avenue  ...         NaN      NaN
# 3                                               NaN  ...         NaN      NaN
# 4  Citi Bike - Cumberland Street & Lafayette Avenue  ...         NaN      NaN
#
#   commercial administrative city_block craft industrial emergency landuse  \
# 0        NaN            NaN        NaN   NaN        NaN       NaN     NaN
# 1        NaN            NaN        NaN   NaN        NaN       NaN     NaN
# 2        NaN            NaN        NaN   NaN        NaN       NaN     NaN
# 3        NaN            NaN        NaN   NaN        NaN       NaN     NaN
# 4        NaN            NaN        NaN   NaN        NaN       NaN     NaN
#
#   office
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN
#
# [5 rows x 30 columns]

# %%
selected = coord_to_boro[['suburb', 'postcode', 'neighbourhood']]

# %%
selected.columns = ['boro', 'zipcode', 'neighborhood']

# %%
stations.reset_index(inplace = True, drop = True)
station_to_boro = pd.concat([stations, selected], axis = 1)
station_to_boro.head()
# Out:
#    Unnamed: 0 station_id                   station_name        lat        lng  \
# 0      542945    4322.06              Bergen St & 4 Ave  40.682564 -73.979898
# 1      793837    4066.15        Bedford Ave & Bergen St  40.676368 -73.952918
# 2      815335    6224.05                W 20 St & 8 Ave  40.743453 -74.000040
# 3      847416    6122.09                2 Ave & E 29 St  40.741724 -73.978093
# 4       15398    4428.02  Cumberland St & Lafayette Ave  40.687534 -73.972652
#
#         boro zipcode                 neighborhood
# 0   Brooklyn   11217                          NaN
# 1   Brooklyn   11226                          NaN
# 2  Manhattan   10011             Chelsea District
# 3  Manhattan   10016  Manhattan Community Board 6
# 4   Brooklyn   11238                          NaN

# %%
station_to_boro = station_to_boro.drop(columns = "Unnamed: 0")

# %%
station_to_boro.boro.isna().sum()
# Out:
# 257

# %%
station_to_boro[station_to_boro.boro.isna()].zipcode.unique()
# Out:
# array(['10458', '10451', '10452', '10454', '10457', '10453', '10455',
#        '10456', '10468', '10459', '10039', '10474', '10467', '10463',
#        '10472', '10460'], dtype=object)

# %%
station_to_boro.boro.unique()
# Out:
# array(['Brooklyn', 'Manhattan', 'The Bronx', 'Queens', 'Kings County',
#        nan, 'Queens County'], dtype=object)

# %%
station_to_boro.boro = station_to_boro.boro.replace('Queens County', 'Queens')
station_to_boro.boro = station_to_boro.boro.replace('Kings County', 'Brooklyn')

# %%
station_to_boro.zipcode = pd.to_numeric(station_to_boro.zipcode)

# %%
station_to_boro.zipcode.describe()
# Out:
# count     1809.000000
# mean     10663.470978
# std        553.987517
# min      10000.000000
# 25%      10032.000000
# 50%      10460.000000
# 75%      11218.000000
# max      11415.000000
# Name: zipcode, dtype: float64

# %%
station_to_boro[(station_to_boro.zipcode >= 10451) & (station_to_boro.zipcode <= 10475)] = 'The Bronx'

# %%
station_to_boro[station_to_boro.boro.isna()].zipcode.unique()
# Out:
# array([10039.0], dtype=object)

# %%
station_to_boro[station_to_boro.zipcode == 10039] = 'Manhattan'

# %%
station_to_boro.to_csv('station_to_boro.csv')

# %% [markdown]
# ## Reference:
# * https://towardsdatascience.com/reverse-geocoding-with-nyc-bike-share-data-cdef427987f8
# * https://stackoverflow.com/questions/35491223/inverting-a-dictionary-with-list-values
# * https://bklyndesigns.com/new-york-city-zip-code/
